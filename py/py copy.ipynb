# %%
# !pip install PyMuPDF pdfplumber pytesseract pandas openpyxl
# !pip install PyPDF2==2.10.0
# Out:
# Requirement already satisfied: PyMuPDF in c:\users\jhack alberth\appdata\local\programs\python\python312\lib\site-packages (1.24.10)
# Requirement already satisfied: pdfplumber in c:\users\jhack alberth\appdata\local\programs\python\python312\lib\site-packages (0.11.4)
# Requirement already satisfied: pytesseract in c:\users\jhack alberth\appdata\local\programs\python\python312\lib\site-packages (0.3.13)
# Requirement already satisfied: pandas in c:\users\jhack alberth\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: openpyxl in c:\users\jhack alberth\appdata\local\programs\python\python312\lib\site-packages (3.1.5)
# Requirement already satisfied: PyMuPDFb==1.24.10 in c:\users\jhack alberth\appdata\local\programs\python\python312\lib\site-packages (from PyMuPDF) (1.24.10)
# Requirement already satisfied: pdfminer.six==20231228 in c:\users\jhack alberth\appdata\local\programs\python\python312\lib\site-packages (from pdfplumber) (20231228)
# Requirement already satisfied: Pillow>=9.1 in c:\users\jhack alberth\appdata\local\programs\python\python312\lib\site-packages (from pdfplumber) (10.4.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\jhack alberth\appdata\local\programs\python\python312\lib\site-packages (from pdfplumber) (4.30.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\jhack alberth\appdata\local\programs\python\python312\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\jhack alberth\appdata\local\programs\python\python312\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (43.0.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\jhack alberth\appdata\roaming\python\python312\site-packages (from pytesseract) (24.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\jhack alberth\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jhack alberth\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jhack alberth\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jhack alberth\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: et-xmlfile in c:\users\jhack alberth\appdata\local\programs\python\python312\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\jhack alberth\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\jhack alberth\appdata\local\programs\python\python312\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.17.0)
# Requirement already satisfied: pycparser in c:\users\jhack alberth\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.22)
# Collecting PyPDF2==2.10.0
#   Downloading PyPDF2-2.10.0-py3-none-any.whl.metadata (5.9 kB)
# Downloading PyPDF2-2.10.0-py3-none-any.whl (208 kB)
# Installing collected packages: PyPDF2
#   Attempting uninstall: PyPDF2
#     Found existing installation: PyPDF2 3.0.1
#     Uninstalling PyPDF2-3.0.1:
#       Successfully uninstalled PyPDF2-3.0.1
# Successfully installed PyPDF2-2.10.0

# %%
import fitz  # PyMuPDF
import pytesseract
from PIL import Image
import pandas as pd
import pdfplumber
import os

# Configurar la ruta a Tesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Ruta del archivo PDF proporcionado (usando barras dobles)
pdf_path = r'C:\xampp\htdocs\php5\py\mnt\data\Convertir.pdf'
output_excel = r'C:\xampp\htdocs\php5\py\mnt\data\output_table.xlsx'

# Asegurarse de que la ruta de salida existe
output_dir = os.path.dirname(output_excel)
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Función para extraer imágenes de las páginas del PDF
def extract_images_from_pdf(pdf_path):
    pdf_document = fitz.open(pdf_path)
    images = []
    for page_num in range(len(pdf_document)):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap()
        img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
        images.append(img)
    return images

# Función para realizar OCR en una imagen y extraer texto
def extract_text_with_ocr(image):
    text = pytesseract.image_to_string(image)
    return text

# Procesar el PDF con pdfplumber para extraer tablas si están estructuradas
def extract_table_from_pdf(pdf_path):
    with pdfplumber.open(pdf_path) as pdf:
        tables = []
        for page in pdf.pages:
            table = page.extract_table()
            if table:
                tables.append(table)
        return tables

# Extraer tablas usando pdfplumber (si es posible)
tables = extract_table_from_pdf(pdf_path)

# Si no se encontraron tablas, extraer las imágenes y realizar OCR
if not tables:
    print("No se encontraron tablas estructuradas. Intentando OCR...")
    images = extract_images_from_pdf(pdf_path)
    ocr_results = [extract_text_with_ocr(image) for image in images]
    
    # Imprimir los resultados del OCR
    for i, result in enumerate(ocr_results):
        print(f"Texto extraído de la página {i+1}:")
        print(result)
    
    # Guardar el resultado OCR en Excel como texto
    df = pd.DataFrame(ocr_results, columns=['Texto OCR'])
    df.to_excel(output_excel, index=False)
    print(f'OCR extraído y guardado en {output_excel}')
else:
    # Convertir las tablas a un DataFrame de pandas y luego a Excel
    print(f"Se encontraron {len(tables)} tabla(s) estructurada(s).")
    df = pd.DataFrame(tables[0])  # Suponiendo que solo queremos la primera tabla
    df.to_excel(output_excel, index=False)
    print(f'Tabla extraída y guardada en {output_excel}')

# %%
import fitz  # PyMuPDF
import pytesseract
from PIL import Image
import pandas as pd
import os

# Configurar la ruta a Tesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Ruta del archivo PDF proporcionado (usando barras dobles)
pdf_path = r'C:\xampp\htdocs\php5\py\mnt\data\Convertir.pdf'
output_excel = r'C:\xampp\htdocs\php5\py\mnt\data\tabla_convertida.xlsx'

# Asegurarse de que la ruta de salida existe
output_dir = os.path.dirname(output_excel)
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Función para extraer imágenes de las páginas del PDF
def extract_images_from_pdf(pdf_path):
    pdf_document = fitz.open(pdf_path)
    images = []
    for page_num in range(len(pdf_document)):
        page = pdf_document.load_page(page_num)
        pix = page.get_pixmap()
        img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
        images.append(img)
    return images

# Función para realizar OCR en una imagen y extraer texto
def extract_text_with_ocr(image):
    text = pytesseract.image_to_string(image)
    return text

# Extraer imágenes de las páginas del PDF
images = extract_images_from_pdf(pdf_path)

# Aplicar OCR a cada imagen
ocr_results = [extract_text_with_ocr(image) for image in images]

# Imprimir los resultados del OCR
for i, result in enumerate(ocr_results):
    print(f"Texto extraído de la página {i+1}:")
    print(result)

# Guardar el resultado OCR en Excel como texto
df = pd.DataFrame(ocr_results, columns=['Texto OCR'])
df.to_excel(output_excel, index=False)
print(f'OCR extraído y guardado en {output_excel}')
# Out:
# Texto extraído de la página 1:
# , UNIVERSIDAD NACIONAL DE INGENIERIA
#
# "Atio de la unidad, la paz y el desarrollo”
#
# Resolucion Rectoral N.° 3953-2023-UNI
# Lima, 18 de diciembre de 2023
#
# Visto:
#
# El Oficio N.° 1198-CA.VA-2023-UNI del 23 de noviembre de 2023 emiido por el Vieerrectorado
# ‘Académico de la Universidad Nacional de Ingenieca,
#
# Considerando:
#
# El Aniculo 18° de la Constitucién Politica del Pert establece que “Cada universidad es auténoma
# ‘en su régimen normativo, de gobierno, académico, administrative y econémico. Las universidades
# ‘0 rigen por sus propias estatutos en el marco de la Constitucién y de las leyes"
#
# ‘Asimismo, ol Aniculo 8° do la Ley N.* 20220 — Ley Universitaria establece que “El Estado reconace
# la autonomia universitaria, que se ejerce de conformidad con lo establecido en la Consttucién, la
# presente Ley y demas normativa aplicable. Esta autonomia se manitiesta en los siguientes
# regimenes: 8.1 Normativo, 8.2 de Gobierno, 8.3 Académico, 8.4 Administrativo y 8.5 Econémico”
#
# Bajo ese contexto, el Articulo 18° del Estatuto de la Universidad establece que “E! Consejo
# Universitario es el maximo érgano de gestion, direccién y de ejecucién académica y administratva
# do la Universidad’
#
# ‘A través del Oficio N.° 1198-CA-VA-2023-UNI del 23 de noviembre de 2023, el Vicerrectorado
# ‘Académico hizo llegar al despacho do! Rectorado, el acuerdo de la Comision Académica del
# Consejo Universitario on su sesién presencia N." 36.2028 del 20 de noviembre de 2023, adoptado
# ‘en mayoria, mediante el cual se acordé proponer al Consejo Universitario la aprobacién del
# Calendario de Actividades Académicas para los Periodos Académicos 2024-1 y 2024-2, que se
# esarrolaran en la Universidad Nacional de Ingenieria,
#
# Estando al Proveldo N° 8484/ALCHN Rect 23 del 27 de noviembre de 2023 de! despacho del
# Rectorado, a lo aprobado por ol Consejo Universitario en la Sesién Ordinaria N.* 19 del 14 do
# diciembre de 2023, y de conformidad con lo dispuesto por e! Articulo 25° dol Estatuto do la
# Universidad Nacional de Ingenieria,
#
# ‘Se resuelve:
#
# ‘Anticulo Unico: Aprobar el Calendario de Actividades Académicas para los Periodas Académicos
# 2024-1 y 2024-2 que se desarrollaran en la Universidad Nacional de Ingenieia
#
# Rogistrese, publiquese, comuniquese y archivese,
#
# Documento fmado digitalmante
# Dr. Pablo Alfonso Lopez Chau Nava
#
# Documento frmado digitalmente Rector
#
# ‘M.Sc. Sonia Anapan Ulloa
#
# ‘Secretaria General Pagina 1 de
#
#
# Texto extraído de la página 2:
# CALENDARIO DE ACTIVIDADES ACADEMICAS EN LA
# UNIVERSIDAD NACIONAL DE INGENIERIA.
#
# PERIODO ACADEMICO 2024 - 1
#
# °  deriveacn
# de Saicudpor |
# 1 |Hata 05 6 ore Medi iteet Arno
# “rast remo pod
# Proce: Fezutad (IGA)
# Examen de Adnisién Ordnaro | Medo~
# 2 | pe t2al 16 efebrero Presence Tresago eto) | Responsable: Postale
# : vas madldades Presa DAD :
# Preseli de expe | ede ~
# 3 | Hasta 122 febrero ingrsanes por Tala Ext a | Resposati: OAD
# ‘acuta Pres: Focus
# ‘De Aditi (rye Waa exes)
# Valdeen de dats personales de | Medo:—
# 4 Hasta et 2240 febeo jae [oe
# Pres: DAD
# De aaistn (nye do exe)
# Genercién decide | Medi
# 5 |2dotateo usar Response DIRCE
# Prose DCE
# estan lara una ca soto
# ‘a comalain de crs pacers ala
# 4g, | asia 125 de treo Presetcn de saciid de |focutad
# Ver Regiments conven edi: iteet Arno
# Responsable Estudio
# Pres: Fut (SICA)
# ede raat
# 7 |Hsta 126 fbr (Cambio dela de Esto | Responsable: Fouts
# Presa: DRCE
# Peseta dsponibiod Tara Soh
# Dodeactn
# 8 | Hasta 129 treo Presetadponibided trae | Medi: ~
# Responsable Docete
# Pros: ecules
# Prepare hararopara minimize cnes
# 9 | Hastaet01 de marzo Registodelacargaporaia [MOU =
# Poca: Facultad
# ec irewet Aa
# Hasta 01 de marzo Presetac de sole
# ” espensabe: Estee
# Ver Regmerto Reser de atioda eet
# reset de SCA por
# 1 |Hesta 03 de marzo Hesaieaid at 61 del Relat
# Tne posbles cabs de pn vo
# conesdcenes
# Presetacn de expen pa
# 12 | Hsia 05 de marzo Frsetann de eoedte P28 | ued: STOUN- Oso
#
# Rosponsabie: Facutades
#
# Procese: DIRCE
#
#
# Texto extraído de la página 3:
# ‘Rionson reeds
#
# ta [Fasoetescemano Pecstacindeepetets ted STD Of
# Verhagen eine arse lat | Raps Far
# Protea: De
# Fos esos du asada
# eseacin de Conataioes [DICE
# 14 ps0 emaao fate prtesmioniones.| Meds ~
# once a
# Frtsa: Dace
# Bsns io OSS
# Peale
# 15 [pao st08semars Pate assepeo esis hd
# Fossa: Etre
# Profs OCEE/ORCE
# fon
# 18 [hasta do mao cones derainta [Repent RCE
# Fotsa: Dace
# Incluye posibles cambios de plan ylo
# Smadar,
# 17 psa 10 emacs ote seRevcopunics [ious
# espa RCE
# ota ce
# Stead a ee ORCE
# ‘Matricula Regular nts matricula uni edu pe/entrar
# 18 foattaténans Novels Coteinte |g Seearmcut
# Mapes efercopeios (Rey tos
# Pot DC oa
# fear
# Genesee natida
# 1» |onteazacemozo Sone Pvp RCE
# | Virtual, realizada por la OERA (en el
# saceiace Taso ioney [Sen
# tors facto dp por mata
# ‘21 | Del 18 al 22 de marzo + Matricula de Greduados, ‘rezagada
# any Cones tee Sicawarecuna
# '* Matricula Rezagada (1) Responsable: Facultades:
# Poteau
# i: Te pe cn
# 22 [oat t8a226emaco Vercaindeatiaus | Rep Fate
# ota Fouts
# Tic STOO
# 2 rasan ceaba Sigs em denaticisals [Rao Foss
# 5 SnanPoea anaes
# Pacis ee olen se
# 24 | 00115 019d ab Retiro Parcal pe &DIRCE om expert STOUN)
# Moors Sate
# Poste bce
# Tie Ss Tenis ORE pe
# 25, | Hata 20 Gabe ot 03 do Retiro Total ser grupales con Unico expediente
#
# mayo
#
# STOUN),
#
#
# Texto extraído de la página 4:
# ede Itanat Rarino
# ‘Respansabie: Estulante
# Procesa: DIRCE
#
# ‘va, Semana
# Medi:
# 26 Del 06 al 10de mayo 8 | Examen Paral i ee
#
# Procesa:Facuitad
#
# ‘5va. Semana (El envio a DIRCE pueden
# ser gupales con inco erpedente
#
# 27 | Del 24 28 do junio 16 | Roto Total (excepciona) | DUN
#
# Responsable: Estuants
#
# Procesa: Feces
#
# ‘va. Somana (actvada pola Facatad 0
# de ofcio porla DIRCE)
# 28 | Del 26a 28 6 junio 18. | Encvesta Docerto Medi: rane Arno
# Responsable: Facutades
# Procesa’ DIRCE
#
# ‘ve. Semana
# 28 | Del Ot al 05 de juito 16 | Examen Final peaicnigens
#
# Procesa:Focutad
#
# ‘T7va, Semana
#
# Media:
#
# 30 | Del 15.194 jlo 48 | Examen Susttuto 4 er
# Procesa:Fectad
#
# 19_|Presentan extemporinea de
#
# 32 |28dejuio recames (ato to)
#
# emis ala DIRCE de vison Coal
#
# 33.02 de agosto 20 | de reciames yrecticacones de
# unl fpo
#
# {as Faciades deberan considera los feados oils para su pogramacion del piodoacadenico 2-1
#
# Texto extraído de la página 5:
# PERIODO ACADEMICO 2024 - 2
#
# Tras. into, no considera nots dl
#
# scoennnauce
# 1 frase psn Preset de Soleo it ao
# e ‘Responsable: Estudiante
# Procesa: Facultad (SIGA)
# ‘Examen de Admision Ordinario | Medio. ~
# 2 [ow ta 18 aanto Prevesti Renee Psiare
# Grscneate oma
# ovat ade d—| to=
# 2 fasta 04 psn csr tatoo 9 spn: 0
# Saat Pov Food
# ‘De Admision (incluye trasiado extemo)
# «|r 8 deo ante coment |=
# Proms 0
# ait re eT
# 5 paste deen sane | ec CE
# Pra CE
#
# El esutiante elatora ura carta solisando
# la conaldacion de cursos pendientes ala
# Presentacion de salciud de facut,
#
# 6 | Hasta 19 40 agosto ‘convalidacion ‘Medio: intranet Aluminio
# Fecpeaae Etre
# es: Pad S14)
# sia
#
# 7 | haa 184 goo canto dean de Estaio | Regetab Facade
# Pees DRCE
# 'Presenta disponiblidad horaria segin
# Drdcactn
#
# «| hase eso Presa depobiad ia {eda
#
# awre ‘Responsable: Docente
# Pocus Foes
# Pps or
# rasta de goto
#
# o |e Faience |p
#
# ede ite Ai
# Preetacin diode
#
# 10 |sata 18 opto Perc Fee Eee
#
# 11 | hata 960 goto Premade Soler |p 6 Ragamanto
# Tie pais ca yo
# radon
#
# Presentacion de expedente para | fi
# 12 |e 21d goto Modo: STOUM 0530
# Reincarporados adios Responsable: Facultades
# Pocus DRCE
# Aesen ines
# 1s [hata 1940p Prmcacin co csee | ae SOM i
#
# Procosa: DIRCE
#
#
# Texto extraído de la página 6:
# Rem expedoris Gola Factad a
# DIRCE
#
# Presentacin de Convaidaiones
# 14 | Hasta 19 de agosto ‘aprobadas por Trasladointera a | Meda: --
# la DCE. Responsable: Fantades
# Procesa: ORCE.
# Por ls mesos bancarosesalecios
# para talfin
# 15 | Hasta 20 de agosto Papo de auoseguro estudians! | Modo: -
# Responsable: Estudlanty
# Procesa’ OCEF /DIRCE
# ‘Modi: =
# 16 | Hasta 20 de agosto Preparer fica dematicula _| Responsable: DIRCE
# Procesa: DIRCE
# Inclye posble caibios de plan yo
# convalidaciones
# 17 | Hasta 21 do agosto Rogisto de Reincorporados | Medi: ~
# Responsable: DIRCE
# Procesa: DIRCE
# Sistema de Matric Ireanet DIRCE
# Matrcuia Regular
# 18 | 02121 a1 24 de agosto Maticula Condionada Media: SIGA-MATRICULA
#
# Maticula de Reincorpoados
#
# Rosponsabie: Estudonte
# Procesa: DICE / Facutad
#
# 2
# corer ae maida ae
# a3 [oaaa code apn eee Pn
# Vu ead CERA Te
# ‘+ Matricula de Traslado Intemo y | SIGA).
# ey (nto spp prmaess
# 21 |oazsas0ceapso SiavaiaceGatatss, | xsi
# TiszeyComeno (og Soa arcu
# + Maticula Rezagada (1)
# ci: ee pan
# 22 | outa s04espe Veranda ata | Rp Fate
# Pros Peta
# Togs STOO- Oe
# 2 frosoedesopanie | 3 Sgacomdematiinals Tes ross
# Pra DCE
# | Sta. Semana (Pasada la semana de
# Reto Pucal tei oe
# ico ao sam SRC cn ogee
# 24 [oamazrsesetente | s |naworua Stow,
# tg Prt mo
# resp Este
# Fre DRCE
# ‘T4va. Semana (El envio a DIRCE pueden
# rgryem on eye
# 2s [rata dee tatoo SO ome
# Fespeab fotare
#
# Procesa: DCE
#
#
# Texto extraído de la página 7:
# Del 14 a 18 de octubre
#
# ‘Examen Parcial
#
# va, Semana
# Media —
# Rosponsabie: Estuanto
# Procesa:Fecuitad
#
# Del 02208 de diciembre
#
# 8
#
# Retiro Total (excepcioal)
#
# 15Va. Semana (Elenvioa DIRCE pueden
# ser grupals con ico expedente
# STOUN)
#
# Med: Intanet Arno
#
# Responsable: Estudlante
# Procesa:Fecuitad
#
# Del 02 a1 08 de diciembre
#
# 8
#
# Encuesta Docente
#
# "va. Semana (actvadaporla Facultad 0
# de of porla DIRCE)
#
# Medi: ranet Anno
#
# Responsable: Facutades
#
# Procesa: DIRCE
#
# Del 09 al 13 de diciembre
#
# 16
#
# ‘eva. Semana
# Media:
# Rosponsabe: Estutlanto
# Provesa:Fenulad
#
# De 23 a 27 de diciembre
#
# 08 de enero de 2025
#
# Examen Susutco
#
# Presentacio extemporénea de
# reclamos (todo tipo)
#
# ‘T7va, Semana
# Meda:—
# Rospansabe: Estutlonte
# Procesa: Feces
#
# Fecha iit parareclanos
# Mede: Oo
# Responsable: Estuiante
# Procesa: Fecitad
#
# 3
#
# 10de enero de 2025,
#
# 2
#
# Romisin ala DIRCE de revision
# de recamosy ecticaiones de
# cualgder too
#
# Fecha Limite para presenta ala DIRCE
# Media: Ofco
#
# ‘Responsable: Fecutades
# Procesa: DIRCE
#
# (a: Las Faaltadesdaberi conalderar os Tero laos para Su programation el paodo cad 2-2
#
#
# OCR extraído y guardado en C:\xampp\htdocs\php5\py\mnt\data\tabla_convertida.xlsx
